# %% [markdown]
# ### Pandas Practice Assignment

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Import Data

# %%
pd.read_csv("https://raw.githubusercontent.com/datadesk/california-coronavirus-scrapers/main/vaccine-zip-codes/data/latest.csv")
# Out:
#             date  zip_code_tabulation_area local_health_jurisdiction  \
# 0     2021-10-05                     93222                      Kern
# 1     2021-10-05                     96063                    Tehama
# 2     2021-10-05                     95833                Sacramento
# 3     2021-10-05                     92342            San Bernardino
# 4     2021-10-05                     95829                Sacramento
# ...          ...                       ...                       ...
# 1672  2021-10-05                     94576                      Napa
# 1673  2021-10-05                     94571                    Solano
# 1674  2021-10-05                     94973                     Marin
# 1675  2021-10-05                     91364               Los Angeles
# 1676  2021-10-05                     91010               Los Angeles
#
#               county  vaccine_equity_metric_quartile  \
# 0               Kern                             2.0
# ...

# %% [markdown]
# #### Create a variable

# %%
vaccine_list = pd.read_csv("https://raw.githubusercontent.com/datadesk/california-coronavirus-scrapers/main/vaccine-zip-codes/data/latest.csv")

# %%
vaccine_list.head()
# Out:
#          date  zip_code_tabulation_area local_health_jurisdiction  \
# 0  2021-10-05                     93222                      Kern
# 1  2021-10-05                     96063                    Tehama
# 2  2021-10-05                     95833                Sacramento
# 3  2021-10-05                     92342            San Bernardino
# 4  2021-10-05                     95829                Sacramento
#
#            county  vaccine_equity_metric_quartile                  vem_source  \
# 0            Kern                             2.0  Healthy Places Index Score
# 1          Tehama                             1.0     CDPH-Derived ZCTA Score
# 2      Sacramento                             2.0  Healthy Places Index Score
# 3  San Bernardino                             2.0  Healthy Places Index Score
# 4      Sacramento                             3.0  Healthy Places Index Score
#
#    age12_plus_population  persons_fully_vaccinated  \
# ...

# %%
vaccine_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1677 entries, 0 to 1676
# Data columns (total 13 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        1677 non-null   object
#  1   zip_code_tabulation_area                    1677 non-null   int64
#  2   local_health_jurisdiction                   1677 non-null   object
#  3   county                                      1677 non-null   object
#  4   vaccine_equity_metric_quartile              1677 non-null   float64
#  5   vem_source                                  1677 non-null   object
#  6   age12_plus_population                       1677 non-null   float64
#  7   persons_fully_vaccinated                    1603 non-null   float64
#  8   persons_partially_vaccinated                1603 non-null   float64
# ...

# %%
vaccine_list['county']
# Out:
# 0                 Kern
# 1               Tehama
# 2           Sacramento
# 3       San Bernardino
# 4           Sacramento
#              ...
# 1672              Napa
# 1673            Solano
# 1674             Marin
# 1675       Los Angeles
# 1676       Los Angeles
# Name: county, Length: 1677, dtype: object

# %%
vaccine_list.county.value_counts()
# Out:
# Los Angeles        277
# San Diego           99
# Orange              87
# San Bernardino      80
# Riverside           70
# Santa Clara         57
# Fresno              55
# Sacramento          51
# Kern                49
# Alameda             47
# Contra Costa        41
# Humboldt            35
# Sonoma              32
# San Joaquin         30
# Tulare              30
# San Mateo           28
# Monterey            27
# Mendocino           26
# San Francisco       26
# Marin               26
# Placer              26
# Ventura             25
# Shasta              25
# Stanislaus          24
# Santa Barbara       22
# Siskiyou            21
# San Luis Obispo     21
# El Dorado           20
# Merced              19
# Butte               17
# Yolo                17
# Calaveras           16
# Santa Cruz          15
# Plumas              15
# Solano              15
# Imperial            14
# Lake                13
# Trinity             13
# Madera              12
# Tehama              12
# ...

# %%
vaccine_list.county.value_counts().reset_index()
# Out:
#               index  county
# 0       Los Angeles     277
# 1         San Diego      99
# 2            Orange      87
# 3    San Bernardino      80
# 4         Riverside      70
# 5       Santa Clara      57
# 6            Fresno      55
# 7        Sacramento      51
# 8              Kern      49
# 9           Alameda      47
# 10     Contra Costa      41
# 11         Humboldt      35
# 12           Sonoma      32
# 13      San Joaquin      30
# 14           Tulare      30
# 15        San Mateo      28
# 16         Monterey      27
# 17        Mendocino      26
# 18    San Francisco      26
# 19            Marin      26
# 20           Placer      26
# 21          Ventura      25
# 22           Shasta      25
# 23       Stanislaus      24
# 24    Santa Barbara      22
# 25         Siskiyou      21
# 26  San Luis Obispo      21
# 27        El Dorado      20
# 28           Merced      19
# 29            Butte      17
# 30             Yolo      17
# 31        Calaveras      16
# ...

# %%
my_county = 'Los Angeles'

# %%
vaccine_list[vaccine_list.county == my_county]
# Out:
#             date  zip_code_tabulation_area local_health_jurisdiction  \
# 59    2021-10-05                     91201               Los Angeles
# 80    2021-10-05                     91001               Los Angeles
# 83    2021-10-05                     91401               Los Angeles
# 85    2021-10-05                     91773               Los Angeles
# 102   2021-10-05                     91303               Los Angeles
# ...          ...                       ...                       ...
# 1660  2021-10-05                     90038               Los Angeles
# 1666  2021-10-05                     90805                Long Beach
# 1667  2021-10-05                     90044               Los Angeles
# 1675  2021-10-05                     91364               Los Angeles
# 1676  2021-10-05                     91010               Los Angeles
#
#            county  vaccine_equity_metric_quartile                  vem_source  \
# ...
