# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Read Voting Data

# %%
url = "https://electproject.github.io/Early-Vote-2020G/CA.html"

# %%
voting = pd.read_html(url)[0]

# %%
voting
# Out:
#                         Party  Returned Ballots  Freq. Distribution  \
# 0                   Democrats           6157827                50.9
# 1                 Republicans           2955528                24.4
# 2  No Party Affiliation/Minor           2977358                24.6
# 3                       TOTAL          12090534               100.0
#
#    Requested Ballots  Return Rate
# 0           10170982         60.5
# 1            5344082         55.3
# 2            6527198         45.6
# 3           22042262         54.9

# %%
voting.head(5)
# Out:
#                         Party  Returned Ballots  Freq. Distribution  \
# 0                   Democrats           6157827                50.9
# 1                 Republicans           2955528                24.4
# 2  No Party Affiliation/Minor           2977358                24.6
# 3                       TOTAL          12090534               100.0
#
#    Requested Ballots  Return Rate
# 0           10170982         60.5
# 1            5344082         55.3
# 2            6527198         45.6
# 3           22042262         54.9

# %% [markdown]
# ### Read Polling Data

# %%
url = "https://www.realclearpolitics.com/epolls/other/kamala_harris_favorableunfavorable-6690.html#polls"

# %%
polling = pd.read_html(url)[1]

# %%
polling
# Out:
#                                  Poll           Date   Sample  Favorable  \
# 0                         RCP Average   9/15 - 10/26       --       42.5
# 1              Economist/YouGovYouGov  10/24 - 10/26  1261 RV       43.0
# 2    Politico/Morning ConsultPolitico  10/22 - 10/24  1999 RV       42.0
# 3                    FOX NewsFOX News  10/16 - 10/19  1003 RV       44.0
# 4              Economist/YouGovYouGov  10/16 - 10/19  1268 RV       42.0
# ..                                ...            ...      ...        ...
# 219            Economist/YouGovYouGov    1/27 - 1/29  1313 RV       35.0
# 220  Politico/Morning ConsultPolitico    1/25 - 1/27  1997 RV       25.0
# 221  Politico/Morning ConsultPolitico    1/18 - 1/22  1996 RV       24.0
# 222              QuinnipiacQuinnipiac  12/12 - 12/17  1147 RV       20.0
# 223                            CNNCNN      9/6 - 9/9   923 RV       22.0
#
#      Unfavorable Spread
# 0           51.0   -8.5
# 1           50.0     -7
# ...

# %%
polling.head(15)
# Out:
#                                 Poll           Date   Sample  Favorable  \
# 0                        RCP Average   9/15 - 10/26       --       42.5
# 1             Economist/YouGovYouGov  10/24 - 10/26  1261 RV       43.0
# 2   Politico/Morning ConsultPolitico  10/22 - 10/24  1999 RV       42.0
# 3                   FOX NewsFOX News  10/16 - 10/19  1003 RV       44.0
# 4             Economist/YouGovYouGov  10/16 - 10/19  1268 RV       42.0
# 5   Politico/Morning ConsultPolitico  10/16 - 10/18  1998 RV       42.0
# 6             Economist/YouGovYouGov   10/9 - 10/12  1266 RV       42.0
# 7   Politico/Morning ConsultPolitico   10/8 - 10/11  1999 RV       45.0
# 8             Economist/YouGovYouGov    10/3 - 10/5  1261 RV       43.0
# 9   Politico/Morning ConsultPolitico    10/2 - 10/4  1998 RV       42.0
# 10            Economist/YouGovYouGov    9/26 - 9/28  1246 RV       43.0
# 11  Politico/Morning ConsultPolitico    9/24 - 9/27  1999 RV       44.0
# ...

# %%
polling.tail(5)
# Out:
#                                  Poll           Date   Sample  Favorable  \
# 219            Economist/YouGovYouGov    1/27 - 1/29  1313 RV       35.0
# 220  Politico/Morning ConsultPolitico    1/25 - 1/27  1997 RV       25.0
# 221  Politico/Morning ConsultPolitico    1/18 - 1/22  1996 RV       24.0
# 222              QuinnipiacQuinnipiac  12/12 - 12/17  1147 RV       20.0
# 223                            CNNCNN      9/6 - 9/9   923 RV       22.0
#
#      Unfavorable Spread
# 219         35.0    Tie
# 220         24.0     +1
# 221         19.0     +5
# 222         22.0     -2
# 223         18.0     +4

# %%
polling.Spread.value_counts().reset_index()
# Out:
#    index  Spread
# 0     +2      18
# 1     -3      17
# 2     -2      16
# 3     +1      15
# 4     -6      15
# 5    Tie      14
# 6     -4      14
# 7     +6      12
# 8     -1       9
# 9     -9       9
# 10    +3       9
# 11    -8       7
# 12   -12       6
# 13    +4       6
# 14    +5       6
# 15   +10       5
# 16   +11       5
# 17   +12       4
# 18   -10       4
# 19   -11       4
# 20    +7       4
# 21    -7       4
# 22    -5       3
# 23    +9       3
# 24   +14       3
# 25   +13       3
# 26    +8       3
# 27   +17       1
# 28   +16       1
# 29  -8.5       1
# 30   -19       1
# 31   +15       1
# 32   +21       1

# %%
Tie = 'Tie'

# %%
polling[polling.Spread == Tie]
# Out:
#                                  Poll           Date   Sample  Favorable  \
# 30               Harvard-HarrisHarris    7/28 - 7/29  1788 RV       45.0
# 36   Politico/Morning ConsultPolitico     7/9 - 7/12  1996 RV       47.0
# 39   Politico/Morning ConsultPolitico    6/25 - 6/28  1989 RV       46.0
# 42               Harvard-HarrisHarris    6/15 - 6/17  2006 RV       43.0
# 44   Politico/Morning ConsultPolitico    6/11 - 6/13  1994 RV       46.0
# 89      NBC News/Wall St. JrnlNBC/WSJ    1/10 - 1/13  1000 RV       41.0
# 90             Economist/YouGovYouGov    1/10 - 1/12  1293 RV       47.0
# 103              Harvard-HarrisHarris  11/17 - 11/19  2205 RV       45.0
# 107     NBC News/Wall St. JrnlNBC/WSJ  10/29 - 10/31  1000 RV       42.0
# 113     NBC News/Wall St. JrnlNBC/WSJ   10/9 - 10/12  1000 RV       41.0
# 192                            CNNCNN    6/28 - 6/30  1466 RV       35.0
# 200              Harvard-HarrisHarris    5/29 - 5/30  1295 RV       33.0
# ...

# %%
polling.to_csv('polling_data.csv', index=False)
